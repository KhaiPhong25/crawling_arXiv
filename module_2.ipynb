# %% [markdown]
# # <center> **Milestone 1 — Module 2: Reference**

# %% [markdown]
# ## **Import libraries**

# %%
import json, time, signal, random, argparse, re, os, threading
from pathlib import Path
from typing import Any, Dict, List, Optional, Set, Tuple
import requests
import psutil
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Config and constants**

# %%
# Version checkpoint
SCHEMA_VERSION = 1

# user agent for request HTTP
USER_AGENT = "arXiv-Refs-Fetcher/1.0 (+github.com/NguyenAn05)"

# regex check format arXiv ID
FOLDER_ID_RE = re.compile(r"^(\d{4})-(\d{5})$")
ARXIV_ID_RE = re.compile(r"^\d{4}\.\d{5}$")
ARXIV_WITH_VER_RE = re.compile(r"^(\d{4}\.\d{5})v\d+$")

REQUIRED_FIELDS = {"paper_title", "authors", "submission_date", "semantic_scholar_id"}

# Size each shard checkpoint
SHARD_SIZE = 100

REFS_ROOT = Path('/content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference')
METAFILE = "metadata.json"
# Path folder checkpoint và file head
CHECKPOINTS_DIR = Path("/content/drive/MyDrive/[Project] Milestone 1/workdir/Checkpoints_reference")
HEAD_PATH = CHECKPOINTS_DIR / "checkpoint_head.json"
FAILED_JSONL_PATH = CHECKPOINTS_DIR / "failed.jsonl"

api_key = "RnqGZQ5DRD6BZaiLhMRq33qTEoH5hsPj6r5Q7z54"  # Replace with the actual API key

# Define headers with API key
headers = {"x-api-key": api_key}

# %% [markdown]
# ## **Measuring memory**

# %% [markdown]
# Function `_proc_mem_bytes()` returns the resident memory (RSS) in bytes for the current process, optionally including child processes, falling back to `/proc/self/status` on Linux if `psutil` is unavailable.

# %%
# -----------------------
# Memory helpers
# -----------------------

def _proc_mem_bytes(include_children: bool = True) -> int:
    """
    Returns resident memory (RSS) in bytes for current process (+ children if requested).
    Falls back to /proc on Linux if psutil is unavailable.
    """
    if psutil is not None:
        proc = psutil.Process(os.getpid())
        rss = proc.memory_info().rss
        if include_children:
            for ch in proc.children(recursive=True):
                try:
                    rss += ch.memory_info().rss
                except Exception:
                    pass
        return rss

    # Fallback (Linux): read VmRSS from /proc/self/status
    try:
        with open("/proc/self/status") as f:
            for line in f:
                if line.startswith("VmRSS:"):
                    parts = line.split()
                    kb = int(parts[1])
                    return kb * 1024
    except Exception:
        pass
    return 0

# %% [markdown]
# Class `MemorySampler()` periodically samples RAM usage, storing `(t_seconds, rss_bytes)` while tracking peak bytes and a time-weighted average of resident memory.

# %%
class MemorySampler(threading.Thread):
    """
    Samples RAM usage over time. Stores (t_seconds, rss_bytes).
    Also keeps a precise time-weighted average (handles uneven sampling).
    """
    def __init__(self, interval: float = 0.5, include_children: bool = True):
        super().__init__(daemon=True)
        self.interval = interval
        self.include_children = include_children
        self.samples: List[Tuple[float, int]] = []
        self._stop_event = threading.Event()
        self.peak_bytes = 0

        # For time-weighted average
        self._last_t: Optional[float] = None
        self._last_v: Optional[int] = None
        self._area: float = 0.0  # integral of bytes over seconds

    def run(self):
        t0 = time.time()
        while not self._stop_event.is_set():
            now_abs = time.time()
            rss = _proc_mem_bytes(self.include_children)
            t_rel = now_abs - t0

            # update series & peak
            self.samples.append((t_rel, rss))
            if rss > self.peak_bytes:
                self.peak_bytes = rss

            # update time-weighted integral
            if self._last_t is not None and self._last_v is not None:
                dt = t_rel - self._last_t
                if dt > 0:
                    # rectangle rule with previous value (stable, avoids spikes)
                    self._area += self._last_v * dt

            self._last_t = t_rel
            self._last_v = rss

            time.sleep(self.interval)

        # one last flush to cover the tail between last sample and stop
        now_abs = time.time()
        if self._last_t is not None and self._last_v is not None and len(self.samples) > 0:
            t_rel = now_abs - (now_abs - (self.samples[-1][0]))  # same as last t_rel
            # nothing to add; sampling already accounted until last recorded time

    def stop(self):
        self._stop_event.set()

    def avg_bytes(self) -> int:
        """
        Returns time-weighted average bytes across the sampled duration.
        If no samples, returns 0.
        """
        if not self.samples:
            return 0
        total_time = self.samples[-1][0] - self.samples[0][0]
        if total_time <= 0:
            # fall back to simple arithmetic mean of values
            return int(sum(v for _, v in self.samples) / max(1, len(self.samples)))
        # Add the area from the last sample to the end as zero-length (already included)
        return int(self._area / total_time)

# %% [markdown]
# ## **Disk helpers**

# %% [markdown]
# Function `_dir_size_bytes()` returns the total size in bytes of all non-symlink regular files under the directory `root`, handling missing or concurrently deleted files robustly.

# %%
# Disk helpers
def _dir_size_bytes(root: Path) -> int:
    """
    Sum of file sizes under root (non-symlink regular files).
    Robust to concurrent file deletes.
    """
    total = 0
    if not root.exists():
        return 0
    for p in root.rglob("*"):
        try:
            if p.is_file() and not p.is_symlink():
                total += p.stat().st_size
        except FileNotFoundError:
            continue
        except Exception:
            continue
    return total

# %% [markdown]
# Function `_sum_dirs_size()` returns the total size in bytes of all files contained in the given list of directories by summing `_dir_size_bytes` for each directory.

# %%
def _sum_dirs_size(dirs: List[Path]) -> int:
    return sum(_dir_size_bytes(Path(d)) for d in dirs)

# %% [markdown]
# Class `DiskWatcher()` periodically samples total disk usage (in bytes) across given directories, recording time series samples and tracking initial, final, and peak usage.

# %%
class DiskWatcher(threading.Thread):
    """
    Samples total bytes across specified directories over time.
    Tracks initial, final, and peak absolute usage.
    """
    def __init__(self, dirs: List[Path], interval: float = 1.0):
        super().__init__(daemon=True)
        self.dirs = [Path(d) for d in dirs]
        self.interval = interval
        self._stop_event = threading.Event()
        self.samples: List[Tuple[float, int]] = []
        self.initial_bytes: Optional[int] = None
        self.final_bytes: Optional[int] = None
        self.peak_bytes: int = 0

    def run(self):
        t0 = time.time()
        self.initial_bytes = _sum_dirs_size(self.dirs)
        cur = self.initial_bytes
        self.peak_bytes = cur
        while not self._stop_event.is_set():
            cur = _sum_dirs_size(self.dirs)
            t_rel = time.time() - t0
            self.samples.append((t_rel, cur))
            if cur > self.peak_bytes:
                self.peak_bytes = cur
            time.sleep(self.interval)

        # final measurement
        self.final_bytes = _sum_dirs_size(self.dirs)
        if self.final_bytes > self.peak_bytes:
            self.peak_bytes = self.final_bytes

    def stop(self):
        self._stop_event.set()

# %% [markdown]
# ## **Processing directory tree metadata**

# %% [markdown]
# Function `folder_to_arxiv_id()` parses `folder_name` with `FOLDER_ID_RE` and returns the matched arXiv ID string, or `None` if it does not match.

# %%
# Function to Convert Folder Name to arXiv ID
def folder_to_arxiv_id(folder_name: str) -> Optional[str]:
    m = FOLDER_ID_RE.match(folder_name.strip())
    if not m:
        return None
    return f"{m.group(1)}.{m.group(2)}"

# %% [markdown]
# Function `normalize_id()` cleans and canonicalizes a raw arXiv ID string (handling dashes and optional version suffix), returning the normalized base ID or `None` if invalid.

# %%
# Function to Normalize an arXiv ID
def normalize_id(raw_id: str) -> Optional[str]:
    cleaned_id = raw_id.strip()
    cleaned_id = cleaned_id.replace("-", ".")

    match_with_version = ARXIV_WITH_VER_RE.match(cleaned_id)
    if match_with_version is not None:
        base_id = match_with_version.group(1)
    else:
        base_id = cleaned_id

    if ARXIV_ID_RE.match(base_id) is not None:
        return base_id
    else:
        return None

# %% [markdown]
# Function `read_id_from_metadata()` reads an arXiv ID from a `metadata.json` file at `meta_path`, normalizes it, and returns the ID or `None` if missing or invalid.

# %%
# Function to Read arXiv ID from metadata.json file
def read_id_from_metadata(meta_path: Path) -> Optional[str]:
    if not meta_path.exists():
        return None
    try:
        with meta_path.open("r", encoding="utf-8") as f:
            data = json.load(f)
    except Exception:
        return None
    if isinstance(data, dict):
        rid = data.get("id")
        if isinstance(rid, str):
            return normalize_id(rid)
        return None
    if isinstance(data, list):
        for item in data:
            rid = (item or {}).get("id")
            if isinstance(rid, str):
                nid = normalize_id(rid)
                if nid:
                    return nid
    return None

# %% [markdown]
# Function `collect_ids_from_tree()` walks direct subdirectories of `root`, extracting unique normalized arXiv IDs from folder names or `metadata.json` files and returning them as a list.

# %%
# Function to Collect All arXiv IDs from a Directory Tree
def collect_ids_from_tree(root: Path) -> List[str]:
    ids: List[str] = []
    seen: Set[str] = set()
    for d in root.iterdir():
        if not d.is_dir():
            continue
        # Prioritize fetching/extracting from the folder name
        base = folder_to_arxiv_id(d.name)
        # Fallback by reading metadata.json in the directory if the folder name is invalid
        if not base:
            base = read_id_from_metadata(d / METAFILE)
        if base and base not in seen:
            seen.add(base)
            ids.append(base)
    return ids

# %% [markdown]
# ## **Checkpoint processing**

# %% [markdown]
# Function `shard_id_for_index()` returns the shard ID for an item index `idx` by integer-dividing it by `SHARD_SIZE`.

# %%
# Function to Get Shard ID from Item Index
def shard_id_for_index(idx: int) -> int:
    return idx // SHARD_SIZE

# %% [markdown]
# Function `shard_path()` ensures the checkpoints directory exists and returns the filesystem path for the given `shard_id` as `cp_{shard_id:06d}.json`.

# %%
# Function to Get Shard Path from Shard ID
def shard_path(shard_id: int) -> Path:
    CHECKPOINTS_DIR.mkdir(parents=True, exist_ok=True)
    return CHECKPOINTS_DIR / f"cp_{shard_id:06d}.json"

# %% [markdown]
# Function `atomic_write_json()` atomically writes JSON data to `path` by dumping to a temporary file and then replacing the target file.

# %%
# Atomically Write JSON File / Write JSON File Atomically
def atomic_write_json(path: Path, data: Any, indent: int = 2) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    tmp = path.with_name(path.name + ".tmp")
    with tmp.open("w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=indent)
    tmp.replace(path)

# %% [markdown]
# Function `load_head()` loads the head checkpoint metadata from `HEAD_PATH`, returning a default schema dict if the file does not yet exist.

# %%
# Function to Load the Head Checkpoint Shard
def load_head() -> dict:
    if not HEAD_PATH.exists():
        return {
            "schema_version": SCHEMA_VERSION,
            "last_index": -1,
            "current_shard_id": 0,
            "stats": {"ok": 0, "fail": 0},
        }
    with HEAD_PATH.open("r", encoding="utf-8") as f:
        return json.load(f)

# %% [markdown]
# Function `save_head()` saves the head checkpoint metadata `head` to `HEAD_PATH` using `atomic_write_json`.

# %%
# Function to Save the Head Checkpoint Shard
def save_head(head: dict) -> None:
    atomic_write_json(HEAD_PATH, head)

# %% [markdown]
# Function `append_jsonl()` appends a single JSON-encoded object as one line to the file at `path`, creating parent directories if needed.

# %%
# Function to Write Objects to the File at Path (target for writing failed IDs)
def append_jsonl(path: Path, obj: dict) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

# %% [markdown]
# Function `init_shard()` creates and returns a new shard metadata dict with schema version, shard ID, start index, open end index, and an empty `processed` map.

# %%
# Function to Initialize a New Shard
def init_shard(shard_id: int, start_index: int) -> dict:
    return {
        "schema_version": SCHEMA_VERSION,
        "shard_id": shard_id,
        "start_index": start_index,
        "end_index": None,
        "processed": {},  # id -> {ok, count, retries, ts}
    }

# %% [markdown]
# Function `load_shard()` loads shard metadata from its JSON file if it exists, or initializes and returns a new shard starting at `start_index_if_new` otherwise.

# %%
# Function to Load a Shard from File, or Initialize New if Not Existent
def load_shard(shard_id: int, start_index_if_new: int) -> dict:
    p = shard_path(shard_id)
    if p.exists():
        with p.open("r", encoding="utf-8") as f:
            return json.load(f)
    return init_shard(shard_id, start_index_if_new)

# %% [markdown]
# Function `save_shard()` saves shard metadata to its JSON file using `atomic_write_json` and the shard’s `shard_id`.

# %%
# Function to Save a Shard to File
def save_shard(shard: dict) -> None:
    atomic_write_json(shard_path(shard["shard_id"]), shard)

# %% [markdown]
# ## **Validate the JSON file, normalize the arXiv ID to a folder path, and ensure the ID is in the correct format**

# %% [markdown]
# Function `is_valid_references_file()` validates a references JSON file’s existence, structure, and required metadata, returning a `(ok, reason)` tuple.

# %%
# Function to validate the references file
def is_valid_references_file(path: Path, min_refs: int = 0, required_fields: set[str] = REQUIRED_FIELDS) -> tuple[bool, str]:
    # Check for file existence
    if not path.exists():
        return False, "file_not_found"

    # Read and validate the JSON file content
    try:
        with path.open("r", encoding="utf-8") as f:
            data = json.load(f)
    except json.JSONDecodeError:
        return False, "json_invalid"
    except OSError as e:
        # fix: use __name__ to get the exception class name
        return False, f"io_error:{type(e).__name__}"

    # Check data structure (must be a dict) and minimum reference count
    if not isinstance(data, dict):
        return False, "root_not_dict"
    if len(data) < min_refs:
        return False, "below_min_refs"

    # Check each sub-entry in the data
    for ref_id, meta in data.items():
        # Check if each entry is a dict
        if not isinstance(meta, dict):
            return False, f"entry_not_dict:{ref_id}"

        # Check for required fields
        missing = required_fields - meta.keys()
        if missing:
            return False, f"missing_fields:{ref_id}:{','.join(sorted(missing))}"

        # Check if Authors is a list of strings
        authors = meta.get("authors")
        if not isinstance(authors, list) or not all(isinstance(a, str) for a in authors):
            return False, f"authors_invalid:{ref_id}"
        # Check if submission_date is a string and not empty (if present)
        sd = meta.get("submission_date")
        if sd is not None and not isinstance(sd, str):
            return False, f"submission_date_not_str:{ref_id}"

        # Check if semantic_scholar_id is a non-empty string
        sid = meta.get("semantic_scholar_id")
        if not sid or not isinstance(sid, str):
            return False, f"paper_id_invalid:{ref_id}"
    return True, "ok"

# %% [markdown]
# Function `id_to_folder()` converts an arXiv ID into its storage folder path under `REFS_ROOT` by replacing `.` with `-`.

# %%
# Function to convert an arXiv ID to a storage folder
def id_to_folder(arxiv_id: str) -> Path:
    return REFS_ROOT / arxiv_id.replace(".", "-")

# %% [markdown]
# Function `validate_arxiv_base_id()` returns `True` if `arxiv_id` matches the base arXiv ID regex `ARXIV_ID_RE`, otherwise `False`.

# %%
# Function to validate the arXiv ID format
def validate_arxiv_base_id(arxiv_id: str) -> bool:
    return bool(ARXIV_ID_RE.match(arxiv_id))

# %% [markdown]
# ## **Extract references from Semantic Scholar**

# %% [markdown]
# Function `extract_arxiv_references_to_file()` fetches references for an arXiv paper from the Semantic Scholar API with retries/backoff, saves them as JSON to `out_path`, and returns the number of stored references.

# %%
# Function to extract references from Semantic Scholar and save to a file
def extract_arxiv_references_to_file(arxiv_id: str, out_path: Path, session: requests.Session, max_attempts: int = 8, base_backoff: float = 5.0) -> int:
    url = f"https://api.semanticscholar.org/graph/v1/paper/arXiv:{arxiv_id}"

    params = {"fields": "references,references.externalIds,references.title,references.paperId,references.authors,references.publicationDate"}

    backoff = base_backoff
    for attempt in range(max_attempts):
        try:
            resp = session.get(url, params=params, headers=headers, timeout=30)
        except requests.RequestException as e:
            # Network error: slight backoff and retry
            sleep_s = min(120, backoff) + random.uniform(0, 0.3)
            print(f"[NET] {arxiv_id}: {e!r}. Retry in {sleep_s:.1f}s")
            time.sleep(sleep_s)
            backoff *= 2
            continue

        # Success: process data and write to file
        if resp.status_code == 200:
            body = resp.json()
            refs = body.get("references", []) or []
            out: Dict[str, Dict[str, Any]] = {}

            for ref in refs:
                ext = ref.get("externalIds") or {}
                arx = ext.get("ArXiv")
                if not arx:
                    continue
                rid = str(arx).replace(".", "-")

                authors = []
                seen = set()
                for a in ref.get("authors", []):
                    name = (a or {}).get("name")
                    if name and name not in seen:
                        authors.append(name)
                        seen.add(name)

                venue = None

                out[rid] = {
                    "paper_title": ref.get("title"),
                    "authors": authors,
                    "submission_date": ref.get("publicationDate"),
                    "semantic_scholar_id": ref.get("paperId")
                }

            atomic_write_json(out_path, out)
            return len(out)

        # Retryable errors
        if resp.status_code in (429, 500, 502, 503, 504):
            sleep_s = min(180, backoff) + random.uniform(0, 0.5)
            print(f"[{resp.status_code}] {arxiv_id}: backoff {sleep_s:.1f}s (attempt {attempt+1}/{max_attempts})")
            time.sleep(sleep_s)
            backoff *= 2
            continue

        # Non-retryable error
        print(f"[HTTP {resp.status_code}] {arxiv_id}: {resp.text[:200]}")
        break

    # Failed
    raise RuntimeError(f"Fetch failed after {max_attempts} attempts")

# %% [markdown]
# ## **Handle program shutdown**

# %% [markdown]
# Function `extract_arxiv_references_to_file()` fetches references for an arXiv paper from the Semantic Scholar API with retries/backoff, saves them as JSON to `out_path`, and returns the number of stored references.

# %%
# Class for graceful program shutdown handling
class GracefulShutdown:
   # Initialize and register signal handlers
    def __init__(self):
        self.stop = False
        for sig in (signal.SIGINT, signal.SIGTERM):
            signal.signal(sig, self._handler)

    # Signal handler (requires 2 parameters: signum, frame)
    def _handler(self, signum, frame):
        print(f"\n[Signal] Caught {signum}. Will stop after current item…")
        self.stop = True

    # Returns the stop status
    @property
    def should_stop(self) -> bool:
        return self.stop

# %% [markdown]
# ## **Parse command-line arguments for the reference-fetching script**

# %% [markdown]
# Class `GracefulShutdown` installs SIGINT/SIGTERM handlers that set an internal stop flag, allowing the program to shut down gracefully after the current item finishes.

# %%
def get_args(argv=None):
    ap = argparse.ArgumentParser(description="Fetch references for arXiv IDs from metadata.json with robust checkpointing")
    ap.add_argument("--metadata", default="metadata.json", help="Path metadata.json")
    ap.add_argument("--refs-root", default=str(REFS_ROOT), help="Root folder to save refs")
    ap.add_argument("--start-index", type=int, default=None, help="Start from specific index (override checkpoint)")
    ap.add_argument("--sleep", type=float, default=1.1, help="Sleep between papers to respect rate limit")
    ap.add_argument("--min-refs", type=int, default=0, help="The minimum number of refs to consider output valid (0 = accept empty)")
    ap.add_argument("--max-attempts", type=int, default=8, help="The maximum number of attempts per ID")
    ap.add_argument("--dry-run", action="store_true", help="Don't write refs file; just log and update checkpoint")
    ap.add_argument("--failed-jsonl", default=str(CHECKPOINTS_DIR / "failed.jsonl" ),help="Path JSON save id fail")

    return ap.parse_args(argv)

# %% [markdown]
# ## **Main process**

# %% [markdown]
# Function `main()` coordinates CLI parsing, arXiv ID discovery, checkpointed reference fetching with rate limiting, resource monitoring, and graceful shutdown for the whole extraction pipeline.

# %%
def main(argv=None):
    t0 = time.perf_counter()
    global REFS_ROOT

    # Parse command line arguments
    args = get_args(argv)

    # Set up storage directory
    REFS_ROOT = Path(args.refs_root)
    REFS_ROOT.mkdir(parents=True, exist_ok=True)

    # Start memory sampler and disk monitor
    mem_sampler = MemorySampler(interval=0.5, include_children=True)
    disk_watcher = DiskWatcher([REFS_ROOT, CHECKPOINTS_DIR], interval=1.0)

    mem_sampler.start()
    disk_watcher.start()

    t0_discovery = time.perf_counter()
    # Read metadata and collect arXiv IDs
    ids = collect_ids_from_tree(REFS_ROOT)
    discovery_time = time.perf_counter() - t0_discovery

    if not ids:
        return
    print(f"Collected {len(ids)} IDs from '{REFS_ROOT}'.")

    print(f"Collected {len(ids)} IDs from {args.metadata}")
    if not ids:
        return

    # Load HEAD checkpoint shard
    head = load_head()


    # Determine starting point
    if args.start_index is not None:
        start_idx = args.start_index
    else:
        start_idx = head.get("last_index", -1) + 1

    start_idx = max(0, start_idx)

    if start_idx >= len(ids):
        print("[Info] Đã xử lý hết danh sách theo HEAD checkpoint.")
        return

    # Load the current shard
    curr_shard_id = shard_id_for_index(start_idx)
    shard = load_shard(curr_shard_id, start_index_if_new=curr_shard_id * SHARD_SIZE)

    # Record the current shard ID
    head["current_shard_id"] = curr_shard_id
    save_head(head)

    # Create shutdown flag for signal handling when needed
    shutdown = GracefulShutdown()
    paper_times = []
    with requests.Session() as sess:
        sess.headers.update({"User-Agent": USER_AGENT, "Accept": "application/json"})

        for idx in range(start_idx, len(ids)):
            t_paper = time.perf_counter()
            # Check if the current ID needs a new shard file
            sid = shard_id_for_index(idx)
            if sid != curr_shard_id:
                shard["end_index"] = idx - 1
                save_shard(shard)
                curr_shard_id = sid
                shard = load_shard(curr_shard_id, start_index_if_new=curr_shard_id * SHARD_SIZE)
                head["current_shard_id"] = curr_shard_id
                save_head(head)

            arxiv_id = ids[idx]
            folder = id_to_folder(arxiv_id)
            folder.mkdir(parents=True, exist_ok=True)
            out_path = folder / "references.json"

            # Skip if a valid file already exists
            ok_existing, _ = is_valid_references_file(out_path, min_refs=args.min_refs)
            if ok_existing:
                try:
                    cnt = len(json.load(out_path.open("r", encoding="utf-8")))
                except Exception:
                    cnt = -1

                # Mark ID as having a valid file, update failed status if present
                prev_retries = shard["processed"].get(arxiv_id, {}).get("retries", 0)
                shard["processed"][arxiv_id] = {"ok": True, "count": cnt, "retries": prev_retries}
                head["last_index"] = idx
                save_shard(shard)
                save_head(head)
                print(f"[SKIP] {arxiv_id}: references.json đã tồn tại (count={cnt}).")


                if shutdown.should_stop:
                    break
                if idx < len(ids) - 1: time.sleep(max(0.0, args.sleep))
                continue

            print(f"[DO ] ({idx+1}/{len(ids)}) {arxiv_id} → {out_path}")

            # Fetch references from ID
            try:
                if args.dry_run:
                    cnt = 0
                else:
                    cnt = extract_arxiv_references_to_file(
                        arxiv_id, out_path, session=sess, max_attempts=args.max_attempts
                    )

                # Validate the newly written file
                if not args.dry_run:
                    ok_new, reason = is_valid_references_file(out_path, min_refs=args.min_refs)
                    if not ok_new:
                        raise RuntimeError(f"Output not valid or below min_refs={args.min_refs}; reason={reason}")

                # Update indices for shard file and head
                prev_retries = shard["processed"].get(arxiv_id, {}).get("retries", 0)
                shard["processed"][arxiv_id] = {"ok": True, "count": cnt, "retries": prev_retries}
                head["stats"]["ok"] += 1
                print(f"[ OK] {arxiv_id}: {cnt} ref")

            except Exception as e:
                head["stats"]["fail"] += 1
                print(f"[ERR] {arxiv_id}: {e!r}")

                append_jsonl(FAILED_JSONL_PATH, {"arxiv_id": arxiv_id, "error": repr(e)})

            finally:
                head["last_index"] = idx
                save_shard(shard)
                save_head(head)
                mem_sampler.stop()
                disk_watcher.stop()
                mem_sampler.join()
                disk_watcher.join()

            dt = time.perf_counter() - t_paper
            paper_times.append(dt)

            # Sleep duration to adhere to rate limit
            if idx < len(ids) - 1:
                time.sleep(max(0.0, args.sleep))

            if shutdown.should_stop:
                print("[Stop] Graceful shutdown requested.")
                break


    # Finalization: close the current shard
    shard["end_index"] = max(shard.get("end_index") or -1, head["last_index"])
    save_shard(shard)
    print(f"Done. HEAD last_index={head['last_index']} | shard={head['current_shard_id']:06d} | OK={head['stats']['ok']} FAIL={head['stats']['fail']}")

    wall_time = time.perf_counter() - t0
    print(f"Wall time: {wall_time:.3f}s")
    print(f"Discovery time : {discovery_time:.3f}s")

    if paper_times:
        avg_time_per_paper = sum(paper_times) / len(paper_times)
        print(
            f"Per-paper time : mean={avg_time_per_paper:.3f}s "
            f"min={min(paper_times):.3f}s max={max(paper_times):.3f}s"
        )
    else:
        print("Per-paper time : mean=0.000s min=N/A max=N/A (no papers)")

    print(
        f"[MEM] peak={mem_sampler.peak_bytes / (1024**2):.1f} MiB | "
        f"avg={mem_sampler.avg_bytes() / (1024**2):.1f} MiB (time-weighted)"
    )

    if disk_watcher.initial_bytes is not None:
        print(
            "[DISK] init={:.1f} MiB | final={:.1f} MiB | peak={:.1f} MiB".format(
                disk_watcher.initial_bytes / (1024**2),
                disk_watcher.final_bytes / (1024**2),
                disk_watcher.peak_bytes / (1024**2),
            )
        )

# %%
main([])
# Out:
# Collected 1501 IDs from '/content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference'.
# Collected 1501 IDs from metadata.json
# [DO ] (1/1501) 2211.14747 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14747/references.json
# [ OK] 2211.14747: 3 ref
# [DO ] (2/1501) 2211.14745 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14745/references.json
# [ OK] 2211.14745: 22 ref
# [DO ] (3/1501) 2211.14744 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14744/references.json
# [ OK] 2211.14744: 5 ref
# [DO ] (4/1501) 2211.14743 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14743/references.json
# [ OK] 2211.14743: 5 ref
# [DO ] (5/1501) 2211.14742 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14742/references.json
# [ OK] 2211.14742: 39 ref
# [DO ] (6/1501) 2211.14741 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14741/references.json
# [ OK] 2211.14741: 1 ref
# [DO ] (7/1501) 2211.14738 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14738/references.json
# [ OK] 2211.14738: 11 ref
# [DO ] (8/1501) 2211.14739 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14739/references.json
# [ OK] 2211.14739: 33 ref
# [DO ] (9/1501) 2211.14740 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14740/references.json
# [ OK] 2211.14740: 0 ref
# [DO ] (10/1501) 2211.14736 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14736/references.json
# [ OK] 2211.14736: 49 ref
# [DO ] (11/1501) 2211.14737 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14737/references.json
# [ OK] 2211.14737: 12 ref
# [DO ] (12/1501) 2211.14735 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14735/references.json
# [ OK] 2211.14735: 23 ref
# [DO ] (13/1501) 2211.14734 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14734/references.json
# [ OK] 2211.14734: 14 ref
# [DO ] (14/1501) 2211.14733 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14733/references.json
# [ OK] 2211.14733: 0 ref
# [DO ] (15/1501) 2211.14732 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14732/references.json
# [ OK] 2211.14732: 265 ref
# [DO ] (16/1501) 2211.14731 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14731/references.json
# [ OK] 2211.14731: 47 ref
# [DO ] (17/1501) 2211.14730 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14730/references.json
# [ OK] 2211.14730: 33 ref
# [DO ] (18/1501) 2211.14729 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14729/references.json
# [ OK] 2211.14729: 27 ref
# [DO ] (19/1501) 2211.14726 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14726/references.json
# [ OK] 2211.14726: 0 ref
# [DO ] (20/1501) 2211.14727 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14727/references.json
# [ OK] 2211.14727: 29 ref
# [DO ] (21/1501) 2211.14728 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14728/references.json
# [ OK] 2211.14728: 5 ref
# [DO ] (22/1501) 2211.14725 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14725/references.json
# [ OK] 2211.14725: 4 ref
# [DO ] (23/1501) 2211.14724 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14724/references.json
# [ OK] 2211.14724: 4 ref
# [DO ] (24/1501) 2211.14723 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14723/references.json
# [ OK] 2211.14723: 2 ref
# [DO ] (25/1501) 2211.14722 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14722/references.json
# [ OK] 2211.14722: 6 ref
# [DO ] (26/1501) 2211.14720 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14720/references.json
# [ OK] 2211.14720: 25 ref
# [DO ] (27/1501) 2211.14721 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14721/references.json
# [ OK] 2211.14721: 13 ref
# [DO ] (28/1501) 2211.14719 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14719/references.json
# [ OK] 2211.14719: 44 ref
# [DO ] (29/1501) 2211.14718 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14718/references.json
# [ OK] 2211.14718: 3 ref
# [DO ] (30/1501) 2211.14716 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14716/references.json
# [ OK] 2211.14716: 19 ref
# [DO ] (31/1501) 2211.14717 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14717/references.json
# [ OK] 2211.14717: 3 ref
# [DO ] (32/1501) 2211.14715 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14715/references.json
# [ OK] 2211.14715: 46 ref
# [DO ] (33/1501) 2211.14714 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14714/references.json
# [ OK] 2211.14714: 6 ref
# [DO ] (34/1501) 2211.14713 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14713/references.json
# [ OK] 2211.14713: 10 ref
# [DO ] (35/1501) 2211.14712 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14712/references.json
# [ OK] 2211.14712: 16 ref
# [DO ] (36/1501) 2211.14711 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14711/references.json
# [ OK] 2211.14711: 0 ref
# [DO ] (37/1501) 2211.14710 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14710/references.json
# [ OK] 2211.14710: 32 ref
# [DO ] (38/1501) 2211.14709 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14709/references.json
# [ OK] 2211.14709: 32 ref
# [DO ] (39/1501) 2211.14708 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14708/references.json
# [ OK] 2211.14708: 8 ref
# [DO ] (40/1501) 2211.14707 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14707/references.json
# [ OK] 2211.14707: 0 ref
# [DO ] (41/1501) 2211.14706 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14706/references.json
# [ OK] 2211.14706: 21 ref
# [DO ] (42/1501) 2211.14705 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14705/references.json
# [ OK] 2211.14705: 23 ref
# [DO ] (43/1501) 2211.14704 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14704/references.json
# [ OK] 2211.14704: 13 ref
# [DO ] (44/1501) 2211.14703 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14703/references.json
# [ OK] 2211.14703: 38 ref
# [DO ] (45/1501) 2211.14702 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14702/references.json
# [ OK] 2211.14702: 11 ref
# [DO ] (46/1501) 2211.14701 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14701/references.json
# [ OK] 2211.14701: 36 ref
# [DO ] (47/1501) 2211.14700 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14700/references.json
# [ OK] 2211.14700: 14 ref
# [DO ] (48/1501) 2211.14699 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14699/references.json
# [ OK] 2211.14699: 49 ref
# [DO ] (49/1501) 2211.14698 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14698/references.json
# [ OK] 2211.14698: 35 ref
# [DO ] (50/1501) 2211.14697 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14697/references.json
# [ OK] 2211.14697: 0 ref
# [DO ] (51/1501) 2211.14695 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14695/references.json
# [ OK] 2211.14695: 24 ref
# [DO ] (52/1501) 2211.14696 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14696/references.json
# [ OK] 2211.14696: 0 ref
# [DO ] (53/1501) 2211.14694 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14694/references.json
# [ OK] 2211.14694: 56 ref
# [DO ] (54/1501) 2211.14693 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14693/references.json
# [ OK] 2211.14693: 0 ref
# [DO ] (55/1501) 2211.14692 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14692/references.json
# [ OK] 2211.14692: 26 ref
# [DO ] (56/1501) 2211.14691 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14691/references.json
# [ OK] 2211.14691: 14 ref
# [DO ] (57/1501) 2211.14690 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14690/references.json
# [ OK] 2211.14690: 9 ref
# [DO ] (58/1501) 2211.14686 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14686/references.json
# [ OK] 2211.14686: 12 ref
# [DO ] (59/1501) 2211.14689 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14689/references.json
# [ OK] 2211.14689: 0 ref
# [DO ] (60/1501) 2211.14688 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14688/references.json
# [429] 2211.14688: backoff 5.1s (attempt 1/8)
# [ OK] 2211.14688: 17 ref
# [DO ] (61/1501) 2211.14687 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14687/references.json
# [ OK] 2211.14687: 17 ref
# [DO ] (62/1501) 2211.14685 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14685/references.json
# [ OK] 2211.14685: 1 ref
# [DO ] (63/1501) 2211.14684 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14684/references.json
# [ OK] 2211.14684: 6 ref
# [DO ] (64/1501) 2211.14683 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14683/references.json
# [ OK] 2211.14683: 43 ref
# [DO ] (65/1501) 2211.14682 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14682/references.json
# [ OK] 2211.14682: 36 ref
# [DO ] (66/1501) 2211.14681 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14681/references.json
# [ OK] 2211.14681: 0 ref
# [DO ] (67/1501) 2211.14680 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14680/references.json
# [ OK] 2211.14680: 42 ref
# [DO ] (68/1501) 2211.14678 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14678/references.json
# [ OK] 2211.14678: 0 ref
# [DO ] (69/1501) 2211.14679 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14679/references.json
# [ OK] 2211.14679: 20 ref
# [DO ] (70/1501) 2211.14677 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14677/references.json
# [ OK] 2211.14677: 3 ref
# [DO ] (71/1501) 2211.14676 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14676/references.json
# [ OK] 2211.14676: 11 ref
# [DO ] (72/1501) 2211.14675 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14675/references.json
# [ OK] 2211.14675: 0 ref
# [DO ] (73/1501) 2211.14674 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14674/references.json
# [ OK] 2211.14674: 5 ref
# [DO ] (74/1501) 2211.14673 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14673/references.json
# [ OK] 2211.14673: 32 ref
# [DO ] (75/1501) 2211.14672 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14672/references.json
# [ OK] 2211.14672: 19 ref
# [DO ] (76/1501) 2211.14669 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14669/references.json
# [ OK] 2211.14669: 40 ref
# [DO ] (77/1501) 2211.14671 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14671/references.json
# [ OK] 2211.14671: 10 ref
# [DO ] (78/1501) 2211.14670 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14670/references.json
# [ OK] 2211.14670: 5 ref
# [DO ] (79/1501) 2211.14668 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14668/references.json
# [ OK] 2211.14668: 33 ref
# [DO ] (80/1501) 2211.14667 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14667/references.json
# [ OK] 2211.14667: 76 ref
# [DO ] (81/1501) 2211.14666 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14666/references.json
# [ OK] 2211.14666: 68 ref
# [DO ] (82/1501) 2211.14665 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14665/references.json
# [ OK] 2211.14665: 6 ref
# [DO ] (83/1501) 2211.14664 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14664/references.json
# [ OK] 2211.14664: 3 ref
# [DO ] (84/1501) 2211.14663 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14663/references.json
# [ OK] 2211.14663: 3 ref
# [DO ] (85/1501) 2211.14662 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14662/references.json
# [ OK] 2211.14662: 3 ref
# [DO ] (86/1501) 2211.14660 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14660/references.json
# [ OK] 2211.14660: 14 ref
# [DO ] (87/1501) 2211.14661 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14661/references.json
# [ OK] 2211.14661: 61 ref
# [DO ] (88/1501) 2211.14659 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14659/references.json
# [ OK] 2211.14659: 12 ref
# [DO ] (89/1501) 2211.14655 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14655/references.json
# [ OK] 2211.14655: 20 ref
# [DO ] (90/1501) 2211.14658 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14658/references.json
# [ OK] 2211.14658: 7 ref
# [DO ] (91/1501) 2211.14657 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14657/references.json
# [ OK] 2211.14657: 41 ref
# [DO ] (92/1501) 2211.14656 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14656/references.json
# [ OK] 2211.14656: 12 ref
# [DO ] (93/1501) 2211.14653 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14653/references.json
# [ OK] 2211.14653: 6 ref
# [DO ] (94/1501) 2211.14654 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14654/references.json
# [ OK] 2211.14654: 4 ref
# [DO ] (95/1501) 2211.14652 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14652/references.json
# [ OK] 2211.14652: 14 ref
# [DO ] (96/1501) 2211.14651 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14651/references.json
# [ OK] 2211.14651: 32 ref
# [DO ] (97/1501) 2211.14650 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14650/references.json
# [ OK] 2211.14650: 8 ref
# [DO ] (98/1501) 2211.14649 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14649/references.json
# [ OK] 2211.14649: 10 ref
# [DO ] (99/1501) 2211.14648 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14648/references.json
# [ OK] 2211.14648: 18 ref
# [DO ] (100/1501) 2211.14646 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14646/references.json
# [ OK] 2211.14646: 33 ref
# [DO ] (101/1501) 2211.14647 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14647/references.json
# [ OK] 2211.14647: 25 ref
# [DO ] (102/1501) 2211.14645 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14645/references.json
# [ OK] 2211.14645: 49 ref
# [DO ] (103/1501) 2211.14644 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14644/references.json
# [ OK] 2211.14644: 26 ref
# [DO ] (104/1501) 2211.14643 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14643/references.json
# [ OK] 2211.14643: 5 ref
# [DO ] (105/1501) 2211.14642 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14642/references.json
# [ OK] 2211.14642: 4 ref
# [DO ] (106/1501) 2211.14641 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14641/references.json
# [ OK] 2211.14641: 1 ref
# [DO ] (107/1501) 2211.14640 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14640/references.json
# [ OK] 2211.14640: 5 ref
# [DO ] (108/1501) 2211.14639 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14639/references.json
# [ OK] 2211.14639: 12 ref
# [DO ] (109/1501) 2211.14637 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14637/references.json
# [ OK] 2211.14637: 59 ref
# [DO ] (110/1501) 2211.14638 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14638/references.json
# [ OK] 2211.14638: 10 ref
# [DO ] (111/1501) 2211.14636 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14636/references.json
# [ OK] 2211.14636: 20 ref
# [DO ] (112/1501) 2211.14635 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14635/references.json
# [ OK] 2211.14635: 45 ref
# [DO ] (113/1501) 2211.14634 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14634/references.json
# [ OK] 2211.14634: 4 ref
# [DO ] (114/1501) 2211.14633 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14633/references.json
# [ OK] 2211.14633: 13 ref
# [DO ] (115/1501) 2211.14632 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14632/references.json
# [ OK] 2211.14632: 12 ref
# [DO ] (116/1501) 2211.14631 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14631/references.json
# [ OK] 2211.14631: 6 ref
# [DO ] (117/1501) 2211.14630 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14630/references.json
# [ OK] 2211.14630: 13 ref
# [DO ] (118/1501) 2211.14625 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14625/references.json
# [ OK] 2211.14625: 14 ref
# [DO ] (119/1501) 2211.14629 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14629/references.json
# [ OK] 2211.14629: 8 ref
# [DO ] (120/1501) 2211.14628 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14628/references.json
# [ OK] 2211.14628: 9 ref
# [DO ] (121/1501) 2211.14627 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14627/references.json
# [ OK] 2211.14627: 34 ref
# [DO ] (122/1501) 2211.14626 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14626/references.json
# [ OK] 2211.14626: 47 ref
# [DO ] (123/1501) 2211.14623 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14623/references.json
# [ OK] 2211.14623: 21 ref
# [DO ] (124/1501) 2211.14624 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14624/references.json
# [ OK] 2211.14624: 7 ref
# [DO ] (125/1501) 2211.14622 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14622/references.json
# [ OK] 2211.14622: 23 ref
# [DO ] (126/1501) 2211.14621 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14621/references.json
# [ OK] 2211.14621: 21 ref
# [DO ] (127/1501) 2211.14620 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14620/references.json
# [ OK] 2211.14620: 6 ref
# [DO ] (128/1501) 2211.14619 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14619/references.json
# [ OK] 2211.14619: 2 ref
# [DO ] (129/1501) 2211.14618 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14618/references.json
# [429] 2211.14618: backoff 5.0s (attempt 1/8)
# [ OK] 2211.14618: 0 ref
# [DO ] (130/1501) 2211.14617 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14617/references.json
# [ OK] 2211.14617: 8 ref
# [DO ] (131/1501) 2211.14616 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14616/references.json
# [ OK] 2211.14616: 5 ref
# [DO ] (132/1501) 2211.14615 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14615/references.json
# [ OK] 2211.14615: 3 ref
# [DO ] (133/1501) 2211.14614 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14614/references.json
# [ OK] 2211.14614: 10 ref
# [DO ] (134/1501) 2211.14613 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14613/references.json
# [ OK] 2211.14613: 0 ref
# [DO ] (135/1501) 2211.14612 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14612/references.json
# [ OK] 2211.14612: 12 ref
# [DO ] (136/1501) 2211.14611 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14611/references.json
# [ OK] 2211.14611: 8 ref
# [DO ] (137/1501) 2211.14610 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14610/references.json
# [ OK] 2211.14610: 18 ref
# [DO ] (138/1501) 2211.14605 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14605/references.json
# [ OK] 2211.14605: 29 ref
# [DO ] (139/1501) 2211.14609 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14609/references.json
# [ OK] 2211.14609: 4 ref
# [DO ] (140/1501) 2211.14608 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14608/references.json
# [ OK] 2211.14608: 4 ref
# [DO ] (141/1501) 2211.14607 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14607/references.json
# [ OK] 2211.14607: 14 ref
# [DO ] (142/1501) 2211.14606 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14606/references.json
# [ OK] 2211.14606: 4 ref
# [DO ] (143/1501) 2211.14604 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14604/references.json
# [ OK] 2211.14604: 40 ref
# [DO ] (144/1501) 2211.14603 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14603/references.json
# [ OK] 2211.14603: 9 ref
# [DO ] (145/1501) 2211.14602 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14602/references.json
# [ OK] 2211.14602: 5 ref
# [DO ] (146/1501) 2211.14601 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14601/references.json
# [ OK] 2211.14601: 65 ref
# [DO ] (147/1501) 2211.14600 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14600/references.json
# [ OK] 2211.14600: 5 ref
# [DO ] (148/1501) 2211.14599 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14599/references.json
# [ OK] 2211.14599: 11 ref
# [DO ] (149/1501) 2211.14598 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14598/references.json
# [ OK] 2211.14598: 4 ref
# [DO ] (150/1501) 2211.14597 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14597/references.json
# [ OK] 2211.14597: 26 ref
# [DO ] (151/1501) 2211.14596 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14596/references.json
# [ OK] 2211.14596: 28 ref
# [DO ] (152/1501) 2211.14595 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14595/references.json
# [ OK] 2211.14595: 15 ref
# [DO ] (153/1501) 2211.14593 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14593/references.json
# [ OK] 2211.14593: 10 ref
# [DO ] (154/1501) 2211.14594 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14594/references.json
# [ OK] 2211.14594: 73 ref
# [DO ] (155/1501) 2211.14592 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14592/references.json
# [ OK] 2211.14592: 1 ref
# [DO ] (156/1501) 2211.14591 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14591/references.json
# [ OK] 2211.14591: 49 ref
# [DO ] (157/1501) 2211.14590 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14590/references.json
# [ OK] 2211.14590: 30 ref
# [DO ] (158/1501) 2211.14589 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14589/references.json
# [ OK] 2211.14589: 54 ref
# [DO ] (159/1501) 2211.14588 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14588/references.json
# [ OK] 2211.14588: 5 ref
# [DO ] (160/1501) 2211.14587 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14587/references.json
# [HTTP 404] 2211.14587: {"error":"Paper with id arXiv:2211.14587 not found"}
#
# [ERR] 2211.14587: RuntimeError('Fetch failed after 8 attempts')
# [DO ] (161/1501) 2211.14586 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14586/references.json
# [ OK] 2211.14586: 25 ref
# [DO ] (162/1501) 2211.14585 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14585/references.json
# [ OK] 2211.14585: 9 ref
# [DO ] (163/1501) 2211.14583 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14583/references.json
# [ OK] 2211.14583: 8 ref
# [DO ] (164/1501) 2211.14584 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14584/references.json
# [ OK] 2211.14584: 5 ref
# [DO ] (165/1501) 2211.14582 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14582/references.json
# [ OK] 2211.14582: 42 ref
# [DO ] (166/1501) 2211.14581 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14581/references.json
# [ OK] 2211.14581: 18 ref
# [DO ] (167/1501) 2211.14580 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14580/references.json
# [ OK] 2211.14580: 21 ref
# [DO ] (168/1501) 2211.14578 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14578/references.json
# [ OK] 2211.14578: 0 ref
# [DO ] (169/1501) 2211.14579 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14579/references.json
# [ OK] 2211.14579: 32 ref
# [DO ] (170/1501) 2211.14575 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14575/references.json
# [ OK] 2211.14575: 73 ref
# [DO ] (171/1501) 2211.14577 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14577/references.json
# [ OK] 2211.14577: 25 ref
# [DO ] (172/1501) 2211.14576 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14576/references.json
# [ OK] 2211.14576: 25 ref
# [DO ] (173/1501) 2211.14574 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14574/references.json
# [ OK] 2211.14574: 6 ref
# [DO ] (174/1501) 2211.14573 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14573/references.json
# [ OK] 2211.14573: 55 ref
# [DO ] (175/1501) 2211.14572 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14572/references.json
# [ OK] 2211.14572: 3 ref
# [DO ] (176/1501) 2211.14571 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14571/references.json
# [ OK] 2211.14571: 5 ref
# [DO ] (177/1501) 2211.14570 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14570/references.json
# [ OK] 2211.14570: 0 ref
# [DO ] (178/1501) 2211.14568 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14568/references.json
# [ OK] 2211.14568: 71 ref
# [DO ] (179/1501) 2211.14569 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14569/references.json
# [ OK] 2211.14569: 66 ref
# [DO ] (180/1501) 2211.14566 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14566/references.json
# [ OK] 2211.14566: 3 ref
# [DO ] (181/1501) 2211.14567 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14567/references.json
# [ OK] 2211.14567: 38 ref
# [DO ] (182/1501) 2211.14564 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14564/references.json
# [ OK] 2211.14564: 25 ref
# [DO ] (183/1501) 2211.14565 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14565/references.json
# [ OK] 2211.14565: 4 ref
# [DO ] (184/1501) 2211.14562 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14562/references.json
# [ OK] 2211.14562: 20 ref
# [DO ] (185/1501) 2211.14563 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14563/references.json
# [ OK] 2211.14563: 41 ref
# [DO ] (186/1501) 2211.14561 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14561/references.json
# [ OK] 2211.14561: 60 ref
# [DO ] (187/1501) 2211.14560 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14560/references.json
# [ OK] 2211.14560: 5 ref
# [DO ] (188/1501) 2211.14558 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14558/references.json
# [ OK] 2211.14558: 24 ref
# [DO ] (189/1501) 2211.14556 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14556/references.json
# [ OK] 2211.14556: 2 ref
# [DO ] (190/1501) 2211.14559 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14559/references.json
# [ OK] 2211.14559: 22 ref
# [DO ] (191/1501) 2211.14557 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14557/references.json
# [ OK] 2211.14557: 21 ref
# [DO ] (192/1501) 2211.14554 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14554/references.json
# [ OK] 2211.14554: 47 ref
# [DO ] (193/1501) 2211.14555 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14555/references.json
# [ OK] 2211.14555: 32 ref
# [DO ] (194/1501) 2211.14553 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14553/references.json
# [ OK] 2211.14553: 0 ref
# [DO ] (195/1501) 2211.14552 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14552/references.json
# [ OK] 2211.14552: 9 ref
# [DO ] (196/1501) 2211.14551 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14551/references.json
# [ OK] 2211.14551: 0 ref
# [DO ] (197/1501) 2211.14550 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14550/references.json
# [ OK] 2211.14550: 0 ref
# [DO ] (198/1501) 2211.14549 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14549/references.json
# [ OK] 2211.14549: 2 ref
# [DO ] (199/1501) 2211.14548 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14548/references.json
# [ OK] 2211.14548: 14 ref
# [DO ] (200/1501) 2211.14544 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14544/references.json
# [ OK] 2211.14544: 26 ref
# [DO ] (201/1501) 2211.14547 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14547/references.json
# [ OK] 2211.14547: 5 ref
# [DO ] (202/1501) 2211.14546 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14546/references.json
# [ OK] 2211.14546: 6 ref
# [DO ] (203/1501) 2211.14545 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14545/references.json
# [ OK] 2211.14545: 36 ref
# [DO ] (204/1501) 2211.14543 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14543/references.json
# [ OK] 2211.14543: 104 ref
# [DO ] (205/1501) 2211.14542 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14542/references.json
# [ OK] 2211.14542: 10 ref
# [DO ] (206/1501) 2211.14541 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14541/references.json
# [ OK] 2211.14541: 4 ref
# [DO ] (207/1501) 2211.14540 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14540/references.json
# [ OK] 2211.14540: 33 ref
# [DO ] (208/1501) 2211.14539 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14539/references.json
# [ OK] 2211.14539: 14 ref
# [DO ] (209/1501) 2211.14538 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14538/references.json
# [ OK] 2211.14538: 19 ref
# [DO ] (210/1501) 2211.14537 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14537/references.json
# [ OK] 2211.14537: 16 ref
# [DO ] (211/1501) 2211.14536 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14536/references.json
# [ OK] 2211.14536: 31 ref
# [DO ] (212/1501) 2211.14535 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14535/references.json
# [ OK] 2211.14535: 9 ref
# [DO ] (213/1501) 2211.14534 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14534/references.json
# [ OK] 2211.14534: 5 ref
# [DO ] (214/1501) 2211.14533 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14533/references.json
# [ OK] 2211.14533: 2 ref
# [DO ] (215/1501) 2211.14532 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14532/references.json
# [ OK] 2211.14532: 4 ref
# [DO ] (216/1501) 2211.14531 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14531/references.json
# [ OK] 2211.14531: 6 ref
# [DO ] (217/1501) 2211.14530 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14530/references.json
# [ OK] 2211.14530: 2 ref
# [DO ] (218/1501) 2211.14529 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14529/references.json
# [ OK] 2211.14529: 9 ref
# [DO ] (219/1501) 2211.14528 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14528/references.json
# [ OK] 2211.14528: 23 ref
# [DO ] (220/1501) 2211.14527 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14527/references.json
# [ OK] 2211.14527: 6 ref
# [DO ] (221/1501) 2211.14526 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14526/references.json
# [ OK] 2211.14526: 7 ref
# [DO ] (222/1501) 2211.14525 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14525/references.json
# [ OK] 2211.14525: 0 ref
# [DO ] (223/1501) 2211.14524 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14524/references.json
# [ OK] 2211.14524: 17 ref
# [DO ] (224/1501) 2211.14523 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14523/references.json
# [ OK] 2211.14523: 33 ref
# [DO ] (225/1501) 2211.14522 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14522/references.json
# [ OK] 2211.14522: 18 ref
# [DO ] (226/1501) 2211.14521 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14521/references.json
# [ OK] 2211.14521: 21 ref
# [DO ] (227/1501) 2211.14520 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14520/references.json
# [ OK] 2211.14520: 4 ref
# [DO ] (228/1501) 2211.14519 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14519/references.json
# [ OK] 2211.14519: 0 ref
# [DO ] (229/1501) 2211.14518 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14518/references.json
# [ OK] 2211.14518: 11 ref
# [DO ] (230/1501) 2211.14517 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14517/references.json
# [ OK] 2211.14517: 6 ref
# [DO ] (231/1501) 2211.14515 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14515/references.json
# [ OK] 2211.14515: 31 ref
# [DO ] (232/1501) 2211.14510 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14510/references.json
# [ OK] 2211.14510: 6 ref
# [DO ] (233/1501) 2211.14516 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14516/references.json
# [ OK] 2211.14516: 29 ref
# [DO ] (234/1501) 2211.14514 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14514/references.json
# [ OK] 2211.14514: 5 ref
# [DO ] (235/1501) 2211.14513 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14513/references.json
# [ OK] 2211.14513: 30 ref
# [DO ] (236/1501) 2211.14512 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14512/references.json
# [ OK] 2211.14512: 42 ref
# [DO ] (237/1501) 2211.14511 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14511/references.json
# [ OK] 2211.14511: 8 ref
# [DO ] (238/1501) 2211.14509 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14509/references.json
# [ OK] 2211.14509: 4 ref
# [DO ] (239/1501) 2211.14508 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14508/references.json
# [ OK] 2211.14508: 20 ref
# [DO ] (240/1501) 2211.14507 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14507/references.json
# [ OK] 2211.14507: 1 ref
# [DO ] (241/1501) 2211.14506 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14506/references.json
# [ OK] 2211.14506: 67 ref
# [DO ] (242/1501) 2211.14505 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14505/references.json
# [ OK] 2211.14505: 9 ref
# [DO ] (243/1501) 2211.14503 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14503/references.json
# [ OK] 2211.14503: 14 ref
# [DO ] (244/1501) 2211.14504 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14504/references.json
# [ OK] 2211.14504: 6 ref
# [DO ] (245/1501) 2211.14502 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14502/references.json
# [ OK] 2211.14502: 23 ref
# [DO ] (246/1501) 2211.14501 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14501/references.json
# [ OK] 2211.14501: 16 ref
# [DO ] (247/1501) 2211.14500 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14500/references.json
# [ OK] 2211.14500: 4 ref
# [DO ] (248/1501) 2211.14499 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14499/references.json
# [ OK] 2211.14499: 8 ref
# [DO ] (249/1501) 2211.14498 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14498/references.json
# [ OK] 2211.14498: 15 ref
# [DO ] (250/1501) 2211.14497 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14497/references.json
# [ OK] 2211.14497: 7 ref
# [DO ] (251/1501) 2211.14495 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14495/references.json
# [ OK] 2211.14495: 21 ref
# [DO ] (252/1501) 2211.14496 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14496/references.json
# [ OK] 2211.14496: 12 ref
# [DO ] (253/1501) 2211.14494 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14494/references.json
# [ OK] 2211.14494: 2 ref
# [DO ] (254/1501) 2211.14491 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14491/references.json
# [ OK] 2211.14491: 20 ref
# [DO ] (255/1501) 2211.14493 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14493/references.json
# [ OK] 2211.14493: 7 ref
# [DO ] (256/1501) 2211.14492 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14492/references.json
# [ OK] 2211.14492: 17 ref
# [DO ] (257/1501) 2211.14490 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14490/references.json
# [ OK] 2211.14490: 25 ref
# [DO ] (258/1501) 2211.14488 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14488/references.json
# [ OK] 2211.14488: 35 ref
# [DO ] (259/1501) 2211.14489 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14489/references.json
# [ OK] 2211.14489: 31 ref
# [DO ] (260/1501) 2211.14487 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14487/references.json
# [ OK] 2211.14487: 48 ref
# [DO ] (261/1501) 2211.14486 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14486/references.json
# [ OK] 2211.14486: 20 ref
# [DO ] (262/1501) 2211.14485 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14485/references.json
# [ OK] 2211.14485: 40 ref
# [DO ] (263/1501) 2211.14483 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14483/references.json
# [ OK] 2211.14483: 1 ref
# [DO ] (264/1501) 2211.14481 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14481/references.json
# [ OK] 2211.14481: 28 ref
# [DO ] (265/1501) 2211.14482 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14482/references.json
# [ OK] 2211.14482: 7 ref
# [DO ] (266/1501) 2211.14480 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14480/references.json
# [ OK] 2211.14480: 1 ref
# [DO ] (267/1501) 2211.14484 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14484/references.json
# [ OK] 2211.14484: 6 ref
# [DO ] (268/1501) 2211.14479 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14479/references.json
# [ OK] 2211.14479: 0 ref
# [DO ] (269/1501) 2211.14478 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14478/references.json
# [ OK] 2211.14478: 17 ref
# [DO ] (270/1501) 2211.14476 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14476/references.json
# [ OK] 2211.14476: 10 ref
# [DO ] (271/1501) 2211.14477 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14477/references.json
# [ OK] 2211.14477: 17 ref
# [DO ] (272/1501) 2211.14473 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14473/references.json
# [ OK] 2211.14473: 5 ref
# [DO ] (273/1501) 2211.14475 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14475/references.json
# [ OK] 2211.14475: 19 ref
# [DO ] (274/1501) 2211.14474 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14474/references.json
# [ OK] 2211.14474: 14 ref
# [DO ] (275/1501) 2211.14472 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14472/references.json
# [ OK] 2211.14472: 16 ref
# [DO ] (276/1501) 2211.14471 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14471/references.json
# [ OK] 2211.14471: 8 ref
# [DO ] (277/1501) 2211.14469 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14469/references.json
# [ OK] 2211.14469: 15 ref
# [DO ] (278/1501) 2211.14468 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14468/references.json
# [ OK] 2211.14468: 15 ref
# [DO ] (279/1501) 2211.14470 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14470/references.json
# [ OK] 2211.14470: 40 ref
# [DO ] (280/1501) 2211.14467 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14467/references.json
# [ OK] 2211.14467: 15 ref
# [DO ] (281/1501) 2211.14466 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14466/references.json
# [HTTP 404] 2211.14466: {"error":"Paper with id arXiv:2211.14466 not found"}
#
# [ERR] 2211.14466: RuntimeError('Fetch failed after 8 attempts')
# [DO ] (282/1501) 2211.14465 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14465/references.json
# [ OK] 2211.14465: 36 ref
# [DO ] (283/1501) 2211.14464 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14464/references.json
# [ OK] 2211.14464: 12 ref
# [DO ] (284/1501) 2211.14463 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14463/references.json
# [ OK] 2211.14463: 33 ref
# [DO ] (285/1501) 2211.14462 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14462/references.json
# [ OK] 2211.14462: 36 ref
# [DO ] (286/1501) 2211.14461 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14461/references.json
# [ OK] 2211.14461: 51 ref
# [DO ] (287/1501) 2211.14460 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14460/references.json
# [ OK] 2211.14460: 48 ref
# [DO ] (288/1501) 2211.14459 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14459/references.json
# [ OK] 2211.14459: 7 ref
# [DO ] (289/1501) 2211.14458 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14458/references.json
# [ OK] 2211.14458: 0 ref
# [DO ] (290/1501) 2211.14456 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14456/references.json
# [ OK] 2211.14456: 38 ref
# [DO ] (291/1501) 2211.14457 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14457/references.json
# [ OK] 2211.14457: 4 ref
# [DO ] (292/1501) 2211.14455 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14455/references.json
# [ OK] 2211.14455: 63 ref
# [DO ] (293/1501) 2211.14453 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14453/references.json
# [ OK] 2211.14453: 27 ref
# [DO ] (294/1501) 2211.14454 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14454/references.json
# [ OK] 2211.14454: 14 ref
# [DO ] (295/1501) 2211.14452 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14452/references.json
# [ OK] 2211.14452: 0 ref
# [DO ] (296/1501) 2211.14451 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14451/references.json
# [ OK] 2211.14451: 45 ref
# [DO ] (297/1501) 2211.14449 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14449/references.json
# [ OK] 2211.14449: 37 ref
# [DO ] (298/1501) 2211.14450 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14450/references.json
# [ OK] 2211.14450: 34 ref
# [DO ] (299/1501) 2211.14448 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14448/references.json
# [ OK] 2211.14448: 20 ref
# [DO ] (300/1501) 2211.14447 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14447/references.json
# [ OK] 2211.14447: 10 ref
# [DO ] (301/1501) 2211.14446 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14446/references.json
# [ OK] 2211.14446: 0 ref
# [DO ] (302/1501) 2211.14443 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14443/references.json
# [ OK] 2211.14443: 18 ref
# ...
# [ OK] 2211.14842: 47 ref
# [DO ] (1404/1501) 2211.14845 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14845/references.json
# [ OK] 2211.14845: 60 ref
# [DO ] (1405/1501) 2211.14844 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14844/references.json
# [429] 2211.14844: backoff 5.4s (attempt 1/8)
# [ OK] 2211.14844: 49 ref
# [DO ] (1406/1501) 2211.14843 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14843/references.json
# [ OK] 2211.14843: 52 ref
# [DO ] (1407/1501) 2211.14841 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14841/references.json
# [ OK] 2211.14841: 25 ref
# [DO ] (1408/1501) 2211.14840 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14840/references.json
# [ OK] 2211.14840: 9 ref
# [DO ] (1409/1501) 2211.14839 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14839/references.json
# [ OK] 2211.14839: 36 ref
# [DO ] (1410/1501) 2211.14838 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14838/references.json
# [ OK] 2211.14838: 30 ref
# [DO ] (1411/1501) 2211.14836 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14836/references.json
# [ OK] 2211.14836: 11 ref
# [DO ] (1412/1501) 2211.14837 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14837/references.json
# [ OK] 2211.14837: 3 ref
# [DO ] (1413/1501) 2211.14835 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14835/references.json
# [ OK] 2211.14835: 60 ref
# [DO ] (1414/1501) 2211.14834 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14834/references.json
# [ OK] 2211.14834: 2 ref
# [DO ] (1415/1501) 2211.14833 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14833/references.json
# [ OK] 2211.14833: 8 ref
# [DO ] (1416/1501) 2211.14832 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14832/references.json
# [ OK] 2211.14832: 8 ref
# [DO ] (1417/1501) 2211.14828 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14828/references.json
# [ OK] 2211.14828: 20 ref
# [DO ] (1418/1501) 2211.14831 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14831/references.json
# [ OK] 2211.14831: 8 ref
# [DO ] (1419/1501) 2211.14830 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14830/references.json
# [ OK] 2211.14830: 116 ref
# [DO ] (1420/1501) 2211.14829 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14829/references.json
# [ OK] 2211.14829: 24 ref
# [DO ] (1421/1501) 2211.14827 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14827/references.json
# [ OK] 2211.14827: 27 ref
# [DO ] (1422/1501) 2211.14826 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14826/references.json
# [ OK] 2211.14826: 51 ref
# [DO ] (1423/1501) 2211.14825 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14825/references.json
# [ OK] 2211.14825: 16 ref
# [DO ] (1424/1501) 2211.14822 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14822/references.json
# [ OK] 2211.14822: 15 ref
# [DO ] (1425/1501) 2211.14823 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14823/references.json
# [ OK] 2211.14823: 57 ref
# [DO ] (1426/1501) 2211.14824 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14824/references.json
# [ OK] 2211.14824: 17 ref
# [DO ] (1427/1501) 2211.14821 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14821/references.json
# [ OK] 2211.14821: 15 ref
# [DO ] (1428/1501) 2211.14819 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14819/references.json
# [ OK] 2211.14819: 77 ref
# [DO ] (1429/1501) 2211.14820 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14820/references.json
# [ OK] 2211.14820: 2 ref
# [DO ] (1430/1501) 2211.14818 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14818/references.json
# [ OK] 2211.14818: 16 ref
# [DO ] (1431/1501) 2211.14816 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14816/references.json
# [ OK] 2211.14816: 12 ref
# [DO ] (1432/1501) 2211.14817 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14817/references.json
# [ OK] 2211.14817: 12 ref
# [DO ] (1433/1501) 2211.14815 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14815/references.json
# [ OK] 2211.14815: 26 ref
# [DO ] (1434/1501) 2211.14814 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14814/references.json
# [ OK] 2211.14814: 3 ref
# [DO ] (1435/1501) 2211.14812 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14812/references.json
# [ OK] 2211.14812: 0 ref
# [DO ] (1436/1501) 2211.14813 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14813/references.json
# [ OK] 2211.14813: 61 ref
# [DO ] (1437/1501) 2211.14811 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14811/references.json
# [ OK] 2211.14811: 17 ref
# [DO ] (1438/1501) 2211.14810 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14810/references.json
# [ OK] 2211.14810: 34 ref
# [DO ] (1439/1501) 2211.14809 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14809/references.json
# [ OK] 2211.14809: 1 ref
# [DO ] (1440/1501) 2211.14808 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14808/references.json
# [ OK] 2211.14808: 23 ref
# [DO ] (1441/1501) 2211.14807 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14807/references.json
# [ OK] 2211.14807: 7 ref
# [DO ] (1442/1501) 2211.14806 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14806/references.json
# [ OK] 2211.14806: 3 ref
# [DO ] (1443/1501) 2211.14805 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14805/references.json
# [ OK] 2211.14805: 23 ref
# [DO ] (1444/1501) 2211.14804 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14804/references.json
# [ OK] 2211.14804: 0 ref
# [DO ] (1445/1501) 2211.14803 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14803/references.json
# [ OK] 2211.14803: 26 ref
# [DO ] (1446/1501) 2211.14802 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14802/references.json
# [ OK] 2211.14802: 17 ref
# [DO ] (1447/1501) 2211.14801 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14801/references.json
# [ OK] 2211.14801: 36 ref
# [DO ] (1448/1501) 2211.14800 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14800/references.json
# [ OK] 2211.14800: 5 ref
# [DO ] (1449/1501) 2211.14799 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14799/references.json
# [ OK] 2211.14799: 6 ref
# [DO ] (1450/1501) 2211.14798 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14798/references.json
# [ OK] 2211.14798: 0 ref
# [DO ] (1451/1501) 2211.14797 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14797/references.json
# [ OK] 2211.14797: 10 ref
# [DO ] (1452/1501) 2211.14796 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14796/references.json
# [ OK] 2211.14796: 0 ref
# [DO ] (1453/1501) 2211.14795 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14795/references.json
# [ OK] 2211.14795: 0 ref
# [DO ] (1454/1501) 2211.14794 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14794/references.json
# [ OK] 2211.14794: 43 ref
# [DO ] (1455/1501) 2211.14792 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14792/references.json
# [ OK] 2211.14792: 74 ref
# [DO ] (1456/1501) 2211.14793 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14793/references.json
# [ OK] 2211.14793: 6 ref
# [DO ] (1457/1501) 2211.14791 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14791/references.json
# [ OK] 2211.14791: 2 ref
# [DO ] (1458/1501) 2211.14790 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14790/references.json
# [ OK] 2211.14790: 1 ref
# [DO ] (1459/1501) 2211.14788 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14788/references.json
# [ OK] 2211.14788: 14 ref
# [DO ] (1460/1501) 2211.14789 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14789/references.json
# [ OK] 2211.14789: 4 ref
# [DO ] (1461/1501) 2211.14787 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14787/references.json
# [ OK] 2211.14787: 2 ref
# [DO ] (1462/1501) 2211.14786 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14786/references.json
# [ OK] 2211.14786: 14 ref
# [DO ] (1463/1501) 2211.14785 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14785/references.json
# [ OK] 2211.14785: 28 ref
# [DO ] (1464/1501) 2211.14784 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14784/references.json
# [ OK] 2211.14784: 1 ref
# [DO ] (1465/1501) 2211.14783 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14783/references.json
# [ OK] 2211.14783: 2 ref
# [DO ] (1466/1501) 2211.14782 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14782/references.json
# [ OK] 2211.14782: 45 ref
# [DO ] (1467/1501) 2211.14781 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14781/references.json
# [ OK] 2211.14781: 1 ref
# [DO ] (1468/1501) 2211.14778 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14778/references.json
# [ OK] 2211.14778: 6 ref
# [DO ] (1469/1501) 2211.14780 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14780/references.json
# [ OK] 2211.14780: 5 ref
# [DO ] (1470/1501) 2211.14779 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14779/references.json
# [ OK] 2211.14779: 9 ref
# [DO ] (1471/1501) 2211.14777 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14777/references.json
# [ OK] 2211.14777: 40 ref
# [DO ] (1472/1501) 2211.14776 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14776/references.json
# [ OK] 2211.14776: 5 ref
# [DO ] (1473/1501) 2211.14775 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14775/references.json
# [ OK] 2211.14775: 43 ref
# [DO ] (1474/1501) 2211.14774 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14774/references.json
# [ OK] 2211.14774: 0 ref
# [DO ] (1475/1501) 2211.14773 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14773/references.json
# [ OK] 2211.14773: 33 ref
# [DO ] (1476/1501) 2211.14772 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14772/references.json
# [ OK] 2211.14772: 0 ref
# [DO ] (1477/1501) 2211.14771 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14771/references.json
# [ OK] 2211.14771: 7 ref
# [DO ] (1478/1501) 2211.14770 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14770/references.json
# [ OK] 2211.14770: 7 ref
# [DO ] (1479/1501) 2211.14769 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14769/references.json
# [ OK] 2211.14769: 31 ref
# [DO ] (1480/1501) 2211.14768 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14768/references.json
# [ OK] 2211.14768: 13 ref
# [DO ] (1481/1501) 2211.14767 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14767/references.json
# [ OK] 2211.14767: 44 ref
# [DO ] (1482/1501) 2211.14766 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14766/references.json
# [ OK] 2211.14766: 12 ref
# [DO ] (1483/1501) 2211.14765 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14765/references.json
# [ OK] 2211.14765: 0 ref
# [DO ] (1484/1501) 2211.14764 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14764/references.json
# [ OK] 2211.14764: 46 ref
# [DO ] (1485/1501) 2211.14762 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14762/references.json
# [ OK] 2211.14762: 68 ref
# [DO ] (1486/1501) 2211.14763 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14763/references.json
# [ OK] 2211.14763: 39 ref
# [DO ] (1487/1501) 2211.14760 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14760/references.json
# [ OK] 2211.14760: 22 ref
# [DO ] (1488/1501) 2211.14761 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14761/references.json
# [ OK] 2211.14761: 10 ref
# [DO ] (1489/1501) 2211.14759 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14759/references.json
# [ OK] 2211.14759: 11 ref
# [DO ] (1490/1501) 2211.14757 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14757/references.json
# [ OK] 2211.14757: 12 ref
# [DO ] (1491/1501) 2211.14758 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14758/references.json
# [ OK] 2211.14758: 47 ref
# [DO ] (1492/1501) 2211.14756 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14756/references.json
# [ OK] 2211.14756: 12 ref
# [DO ] (1493/1501) 2211.14755 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14755/references.json
# [ OK] 2211.14755: 1 ref
# [DO ] (1494/1501) 2211.14754 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14754/references.json
# [ OK] 2211.14754: 9 ref
# [DO ] (1495/1501) 2211.14753 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14753/references.json
# [ OK] 2211.14753: 23 ref
# [DO ] (1496/1501) 2211.14746 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14746/references.json
# [ OK] 2211.14746: 1 ref
# [DO ] (1497/1501) 2211.14752 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14752/references.json
# [ OK] 2211.14752: 21 ref
# [DO ] (1498/1501) 2211.14751 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14751/references.json
# [ OK] 2211.14751: 35 ref
# [DO ] (1499/1501) 2211.14749 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14749/references.json
# [ OK] 2211.14749: 0 ref
# [DO ] (1500/1501) 2211.14750 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14750/references.json
# [ OK] 2211.14750: 17 ref
# [DO ] (1501/1501) 2211.14748 → /content/drive/MyDrive/[Project] Milestone 1/workdir/metadata and reference/2211-14748/references.json
# [ OK] 2211.14748: 1 ref
# Done. HEAD last_index=1500 | shard=000015 | OK=1495 FAIL=6
# Wall time: 2866.841s
# Discovery time : 5.839s
# Per-paper time : mean=0.806s min=0.221s max=99.134s
# [MEM] peak=106.3 MiB | avg=105.7 MiB (time-weighted)
# [DISK] init=0.5 MiB | final=0.5 MiB | peak=0.5 MiB
